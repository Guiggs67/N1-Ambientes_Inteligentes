# %% [markdown]
# # **1.Descrição do DataSet**

# %% [markdown]
# A base de dados demonstra uam lista de recomendação de filmes em um período de avaliação que vai de 29 de março de 1996 até 24 de setembro de 2018. Ela se baseia em uma avaliação de até 5 estrelas e marcações de texto, sendo 100.836 avaliações e 3.683 maracações feitas por um total de 610 usuários. Os dados foram retirados do link a seguir: https://grouplens.org/datasets/movielens/

# %% [markdown]
# # 1.1.Importando dados

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/sample_data/movies.csv')

# %%
df2 = pd.read_csv('/content/sample_data/links.csv')

# %%
df3 = pd.read_csv('/content/sample_data/ratings.csv')

# %%
df4 = pd.read_csv('/content/sample_data/tags.csv')

# %% [markdown]
# # **2. Definição das linhas**

# %% [markdown]
# Linhas de movies.csv:
# - Id do filme(int64);
# - Titúlo com ano de (object);
# - Genêro(object).

# %%
df1
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %% [markdown]
# Linhas de links.csv:
#
# - Id do filme(int64);
# - Id do Imdb(int64);
# - Id do database(float64).

# %%
df2
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %% [markdown]
# Linhas de ratings.csv:
#
# - Id do usuário(int64);
# - Id do filme(int64);
# - Avaliação(float64);
# - Data e hora da avaliação(int64);

# %%
df3
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# Linhas de tags.csv:
#
# - Id do usuário(int64);
# - Id do filme(int64);
# - Tag(object);
# - Data e hora da inserção da tag(int64).

# %%
df4
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %% [markdown]
# # **3. Identificação de problemas**

# %% [markdown]
# O código possui coluna com nome que não está explícito, dificultando identificação.

# %% [markdown]
# O código possui linhas vazias, as quais podem ser filtradas.

# %% [markdown]
# # **4. Correção de imperfeições**

# %%
# Renomeando as coluna de
df2.rename(columns={
    'tmdbId': 'DatabaseMovieid'
}, inplace=True)

# %%
df2
# Out:
#       movieId   imdbId  DatabaseMovieid
# 0           1   114709            862.0
# 1           2   113497           8844.0
# 2           3   113228          15602.0
# 3           4   114885          31357.0
# 4           5   113041          11862.0
# ...       ...      ...              ...
# 9737   193581  5476944         432131.0
# 9738   193583  5914996         445030.0
# 9739   193585  6397426         479308.0
# 9740   193587  8391976         483455.0
# 9741   193609   101726          37891.0
#
# [9742 rows x 3 columns]

# %%
#Removendo linhas vazias
df2_limpo = df2.dropna(subset=['DatabaseMovieid'])

# %%
df2_limpo
# Out:
#       movieId   imdbId  DatabaseMovieid
# 0           1   114709            862.0
# 1           2   113497           8844.0
# 2           3   113228          15602.0
# 3           4   114885          31357.0
# 4           5   113041          11862.0
# ...       ...      ...              ...
# 9737   193581  5476944         432131.0
# 9738   193583  5914996         445030.0
# 9739   193585  6397426         479308.0
# 9740   193587  8391976         483455.0
# 9741   193609   101726          37891.0
#
# [9734 rows x 3 columns]
